# %% [markdown]
# Lekce 3
#
# "otevírání" do proměnných (variable unpacking) .split()
# map, zip, filter
# while(jak ho v sonic pi stopnout?) a for cyklus (indexace vs iterace)
# range, len
# klíčová slova break a continue

# %% [markdown]
# # Lekce 3 - Cykly
