# %% [markdown]
# Lekce 2
#
# standartní vstup - input()
# datové typy
# standartní výstup - print/play
# rozhodovací struktury - if, elif, else
# porovnánací operátory (==, !=, >, <, >=, <=)
# logické operatory

# %% [markdown]
# # Lekce 2 - Vstupy a logické rozhodování
