# %% [markdown]
# Lekce 1
#
# hodnota vs "print" hodnoty
# aritmetické operace (+-*/), modulo, celociselne deleni,
# proměnné

# %% [markdown]
# # Lekce 1 - Hodnoty, operace a proměnné
#
# Na úplný začátek si stručně představme Python a proč s ním budeme pracovat. Python, programovací jazyk, který je populární pro svou jednoduchost, je pochopitelný i pro člověka nového ve světe programování. Přes svoji jednoduchost je Python k dnešku jedním z nejpoužívanějších programovacích jazyků. Je využíván řadou profesionálů napříč různými podobory ve světe technologií. My se pokusíme nalézt řešení pro zadané úlohy a zapsat tato řešení algoritmicky do Pythonu tak, aby vykonal naše záměry.
#
# Programovat budeme společně do takto strukturovaných lekcí, kde je klíčové načítat text mezi kapitolami a cvičeními, jelikož cvičení z těchto textů konceptuálně vycházejí.
#
# Pro spuštění kódu v buňce klikněte na ikonu "spustit buňku" (klávesová zkratka: _shift + enter_, nebo _ctrl + alt + enter_).
#
# Pokud vše proběhne v pořádku, oběví se zelená "fajvka" v levém rohu těsně pod spuštěnou buňkou.

# %% [markdown]
# ## Kapitola 1.1 Hrajeme si s čísly
#
# V této kapitole zjistíme, jak používat hodnoty
#
# Spusťme si buňku níže, měli bychom tím spustit první funkční program, který nás pozdraví.

# %%
print("Ahoj studente!")
# Out:
# Ahoj studente!

# %% [markdown]
# Nebaví vás počítání v matematice? Příklady které nemají konce? Python nám s výpočty může velmi snadno pomoci, jelikož může posloužit jako kalkulačka.
# Dnes se společně podíváme na následující matematické operace:
#
# * součet: +
# * rozdíl: -
# * součin: *
# * podíl: /
# * celočíselný podíl: //
# * modulo: %
# * mocnina: **
#
# Zkusme si přečíst kód níže, a odhadnout co bude dělat. Poté ho spusťme.

# %%
10+15
# Out:
# 25

# %% [markdown]
# ### cvičení 1.1.1: Aritmetické operace
#
# Mějme čísla 10 a 4<br>
# Zkusme napsat program, který vytiskne:
# * součet
# * rozdíl
# * součin
# * podíl

# %% [markdown]
# Pokud bychom napsali nějakou syntaktickou nebo logickou chybu, vyvolá python výjimku se základním popisem co bylo špatně a na jakém řádku. Takový výpis je velice užitečný při hledání chyb. viz buňka níže

# %%
2 *
# Out:
#   Cell In[24], line 1
#     2 *
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### cvičení 1.1.2: Celočíselné dělení
#
# Odhadněte, jaké budou výsledky celočíselného dělení čísla 10 čísly:
# * 2
# * 4
# * 6
# * 8
# * 10
#
# Ověřte zadáním výrazů do buňěk<br>
# Celočíslené dělení má znak: //

# %% [markdown]
# ### cvičení 1.1.2:
#
# Operace modulo nám vrací zbytek po celočísleném dělení číslem
# Značí se pomocí znaku: %<br>
# příklad: ```20 % 3```<br>
# První číslo je vždy dělenec a druhé dělitel
#
#
# Vyřešmě pro dvojice čísel:
# * 10 a 2
# * 10 a 4
# * 10 a 6
# * 10 a 8
# * 10 a 10
# * 12 a 10
#
# Pokusme se vyřešit odhadem a pak opět ověřit pomocí zapsaní výrazů do buňěk

# %% [markdown]
# ### Cvičení 1.1.4: Mocniny dvojky
#
# Dalším výrazem, který budeme často používat je mocnina, která se značí dvěma znaky pro násobení ```**```
# pojďme si společně zavzpomínat na dvojkovou soustavu, která je nedílnou součástí informatiky
#
#     2 na 0
#     2 na 1
#     2 na 2
#     2 na 4
#     2 na 10
#     2 na 20

# %% [markdown]
# ## Kapitola 1.2: Celá vs. desetinná čísla
#
# V pythonu se nejčastěji setkáte s dvěma typy číselných hodnot
# * celá čísla (integer tzv. int)
# * desetinná čísla (floating point number tzv. float)

# %%
1.5 + 3.33
# Out:
# 4.83

# %% [markdown]
# Všimli jste si zajímavého faktu, že se na místo desetinné čárky píše desetinná tečka? Je to častá situace, ve které se chybuje.
#
# Pokud budete pracovat s celými a desetinnými čísly dohromady, Python automaticky předeve výsledek na desetinné číslo.

# %%
10 + 2.34
# Out:
# 12.34

# %% [markdown]
# ## Kapitola 1.3: Pravidla závorkování výrazů
#
# Závorkování funguje stejně tak, jak ho znáte například z matematiky. Závorkujeme jednoduchými závorkami ()<br>
# Složené a hranaté závorky mají specifické využití, ke kterému časem dojdeme.
#
# Zkusme odhadnout jaký bude výsledek výrazu níže a ověřte spuštěním kódu

# %%
5 + 2*(10 - (5 + 2*4))
# Out:
# -1

# %% [markdown]
# ### Cvičení 1.3.1: Známka z informatiky
#
# Žák/yně obdržel/a v tomto pololetí následující známky z informatiky: 2, 3, 2, 4, 1.
# Zjistěte a vypište na obrazovku aritmetický průměr známek

# %% [markdown]
# ### Cvičení 1.3.2: Videoherní studio
#
# Nezávislý videoherní vývojář, po prvních 5 pracovních dnech od zahájení prodejů své nové hry, prodal následující počty kopií:
# 1. den: 42 kopií
# 2. den: 87 kopií
# 3. den: 56 kopií
# 4. den: 46 kopií
# 5. den: 33 kopií
#
# Vypočítejte celkový obrat za těchto pět dní v případě, že jedna kopie hry se prodává za 399Kč

# %% [markdown]
# Vypočítejte průměrný denní obrat

# %% [markdown]
# ## Kapitola 1.4 Proměnné
#
# Častokrát je velmi neefektivní používat hodnoty napřímo a lepším efektivnějším způsobem je využívat proměnných.<br>
#
# Proměnnou je nejlepší představit si jako šuplík nebo krabičku, do které vložíte hodnotu a tento šuplík/krabičku si pojmenujete.
# Poté přistupujete k hodnotě v proměnné díky tomuto vytvořenému názvu.<br>
# Proměnnou vytvoříme následovně:
# ```název_proměnné = hodnota```

# %%
leden_výplata = 10000
únor_výplata = 12000
celkem = leden_výplata + únor_výplata
celkem
# Out:
# 22000

# %% [markdown]
# Proměnné se nemohou jmenovat jakkoliv:
#   * Nesmí začínat číslicí
#   * Nesmí obsahovat speciální znaky
#   * Při názvech složených z více slov je mezera k oddělení slov chyba a zpravidla se používá podtržítko tzv.snake_case

# %% [markdown]
# ### Cvičení 1.4.2: Práce s proměnnými
#
# Proveďme následující kroky:
# 1. vytvořme proměnnou _A_ s hodnotou 20
# 2. vytvořme proměnnou _B_ s hodnotou 5
# 3. vynásobme hodnoty proměnné _A_ a _B_ a uložme výsledek do proměnné _vysledek_
# 4. vytvořme proměnnou _C_, která se bude rovnat _B_ děleno _A_
# 5. do proměnné _vysledek_ uložme hodnotu proměnné vysledek vynásobený proměnnou C
# 6. zobraz vysledek

# %% [markdown]
# ### Cvičení 1.4.2: Dovolená se slevou
#
# Proveďme následující kroky:
# 1. vytvořme proměnnou _dovolena_
# 2. uložme do proměnné _dovolena_ hodnotu 75999
# 3. vytvořme proměnnou vanocni_sleva
# 4. do proměnné vanocni_sleva uložme hodnotu slevy, která bude v řádu 5 procent z ceny dovolené
# 5. do proměnné zlevnena_dovolena uložme hodnotu dovolene po slevě
# 6. vypišme cenu dovolené po slevě.

# %% [markdown]
# ## Kapitola 1.5: Změna hodnoty proměnné
#
# V některých případech je třeba měnit hodnoty proměnných v průběhu programu. python nám umožňuje takový zápis zkrátit.
# Níže vidíte přehled zkráceného zápisu aritmetických operací i jejich klasickými variantami:
#
# * A += výraz      ekvivalent výrazu A = A + výraz
# * A -= výraz      ekvivalent výrazu A = A - výraz
# * A *= výraz      ekvivalent výrazu A = A * výraz
# * A /= výraz      ekvivalent výrazu A = A / výraz
# * A //= výraz     ekvivalent výrazu A = A // výraz
# * A %= výraz      ekvivalent výrazu A = A % výraz
# * A **= výraz     ekvivalent výrazu A = A ** výraz

# %%
A = 10
A += 20
A
# Out:
# 30

# %%
A = 10
A **= 2
A
# Out:
# 100

# %% [markdown]
# ### Cvičení 1.5.1:  Přepis hodnoty za chodu
#
# Proveďte postupně kroky:
# 1. Vytvořte proměnnou A
# 2. Do proměnné A uložte hodnotu 2
# 3. Upravte hodnotu v proměnné A vynásobením 5
# 4. Upravte hodnotu v proměnné A umocněním 2
# 5. Upravte hodnotu v proměnné A odečtením 50
# 6. Upravte hodnotu v proměnné A vydělením 10
# 7. Upravte hodnotu v proměnné A modulo 4
# 8. Vypočítejte výsledek v hlavě
# 9. Ověřte si výsledek tiskem hodnoty v programu a porovnejte s myšlenou hodnotou

# %% [markdown]
# ### Cvičení 1.5.2: Dělitelnost číslem
#
# Proveďte následující kroky:
# 1. vytvořte proměnnou _cislo_
# 2. uložte do proměnné _cislo_ hodnotu _30_
# 3. změnte hodnotu proměnné _cislo_ pomocí příkazu _%= 3_
# 4. vytiskněte hodnotu v proměnné _cislo_ na obrazovku
#
# Pokud je výsledek proměnné 0, pak je původní zadané číslo dělitelné 3 beze zbytku, Pokud vyšel výsledek různý od nuly (1,nebo 2) pak číslo není dělitelné 3 beze zbytku

# %% [markdown]
# ### Cvičení 1.5.3: sudost a lichost
#
# Použijte znalosti z předešlého příkladu pro vytvoření programu, který umí odhalit zda je číslo v proměnné sudé nebo liché.

# %% [markdown]
# ## Kapitola 1.6: Zabudované funkce
#
# Funkce jsou v programovacích používány pro vykonání činnosti, k této své činnosti často vyžadují nějaký vstupní údaj (parametr) a mohou vracet nějakou hodnotu (výstup). V Pythonu je k dispozici mnoho zabudovaných funkcí, které můžeme využít.
#
# Představíme si prozatím funkce 'abs()', round() a funkci na generování náhodných čísel random()
#
# Funkce abs() je funkce, která přijme hodnotu, ze které vytvoří a vrátí absolutní hodnotu

# %%
a = -50
abs(a)

# %% [markdown]
# Do funkcí lze zapisovat celé výrazy.

# %%
abs(150/3 - 20**2)

# %% [markdown]
# #### Cvičení 1.7.1 Vzdálenost dvou objektů v 1D
#
# Napište program, který spočítá vzdálenost dvou objektů od sebe. Pro jednoduchost zatím počítáme s tím, že objekty stojí v řadě, tedy mají jen jednu souřadnici x. Vzdálenost bude vždy kladná hodnota, tudíž pokud je je první objekt na souřadnici `x1 = -2` a druhý na souřadnici `x2 = 4`, pak výsledná vzdálenost bude 6. Pro řešení použijte absolutní hodnotu.

# %% [markdown]
# #### Cvičení 1.7.2 Zavolání zaokrouhlování
#
# Další zabudouvanou užitečnou funkcí je funkce pro zaokrouhlování. Tato funkce se jmenuje `round`. Vaším úkolem je naučit se volat tuto funkci zadáním správných argumentů za parametry, jejichž pořadí a význam naleznete v oficiální dokumentaci [ZDE](https://docs.python.org/3/library/functions.html#round).
#
# Proveďte následující úkoly:
# 1. Zaokrouhlete číslo 3.141592 na 3 desetinná místa
# 2. Zaokrouhlete číslo 3.141592 na 1 desetinné místo
# 3. Zaokrouhlete číslo 3.141592 na celé číslo

# %% [markdown]
# #### Cvičení 1.7.3 Výpočet doby jízdy
#
# Napište program, do kterého zadáte celkovou dráhu v km, kterou chcete urazit automobilem a průměrnou rychlost vašeho automobilu v km/h. Program spočítá, kolik hodin vám cesta zabere a výsledek zaokrouhlí na 2 desetinná místa.

# %% [markdown]
# ### Téma 1.8 Matematické funkce
#
# Při vašem studiu programování narazíte na problémy, pro jejichž vyřešení budete potřebovat funkce, které nejsou zabudované v jazyce Python a budete si je muset dodatečně nahrát. Tyto další přídavné funkce se přidávají do tzv. modulů.
#
# Modul se nahrává příkazem import, po kterém následuje název modulu. Poté můžete pomocí názvu modulu a tečky vyvolat funkce. Editor kódu vám bude názvy napovídat, ale můžete se na funkce a jejich popis podívat i do manuálu jazyka Python. Google Colab vám názvy funkcí může zobrazit tak, že napíšete math. a následuje stisk klávesy tabulátoru.
#
# Jeden z nejdůležitějších modulů je modul `math`, který obsahuje matematické funkce jako je například odmocnina `sqrt`, goniometrické funkce sinus `sin`, cosinus `cos` a tangens `tan`, nebo logaritmus `log`.

# %%
import math

#umísti kurzor těsně za tečku a zmáčkni tabulátor
math.

# %% [markdown]
# #### Cvičení 1.8.1 Odmocnina
#
# Napište program, který přijme číslo do proměnné A a vypíše na obrazovku hodnotu druhé odmocniny čísla v proměnné A. Zkuste pomocí internetu zjistit, jaká funkce z knihovny math musí být použita a jak se volá.

# %% [markdown]
# #### Cvičení 1.8.2 Ověření goniometrického vzorce
#
# V goniometrii platí jeden elegantní vzorec, který říká, že sinus na druhou + cosinus na druhou libovolného čísla je roven 1. Ověřte tento vzorec [ZDE](https://www.matweb.cz/goniometricke-vzorce/) (je první v odkazu).

# %%
import math
x = math.pi
math.sin(x)**2 + math.cos(x)**2
